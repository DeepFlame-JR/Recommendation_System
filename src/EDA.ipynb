# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset
# https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset?select=ratings.csv

# %%
import os 
import warnings
warnings.filterwarnings("ignore")

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for dirname, _, filenames in os.walk('/content/drive/MyDrive/GitHub/Recommendation_System/src/data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/movies_metadata.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/links.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/links_small.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/credits.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/ratings_small.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/ratings.csv
# /content/drive/MyDrive/GitHub/Recommendation_System/src/data/keywords.csv
